# %%
# HOMEWORK2 _ GÜLÇİN SÖNMEZ


# nested dictionary used
users = {
    
    '1':{                                          #Each dictionary should represent a cv.
        "Name and Surname":"Selma Tosun",
        "Email":"info@selma.com",
      "Phone ":5532245161,
      "Adres":"ANKARA",
      "Doğum Tarihi": 1996,
      "Ünvan":"Bilgisayar Mühendisi",
      "mezuniyet yılı":2020,
      "Hobiler": "yüzme, seyahat",
      "ingilizce":"orta seviye",
     "iş deneyimi":"Turkcell de halen çalışıyor"
         },
    
    '2':{                                            #Each dictionary should represent a cv.
        "Name and Surname":"Mert Günok",
        "Email": "info@mertgunok.com",
        "Phone ":5532256756,
        "Adres":"izmit",
         "Doğum Tarihi": 1992,
        "Ünvan":"Yazılım Mühendisi",
        "mezuniyet yılı":2021,
        "Hobiler": "tenis, futbol",
         "ingilizce":"ileri seviye",
        "iş deneyimi":"yok"
         },
    
    '3':{                                             #Each dictionary should represent a cv.              
        "Name and Surname":"Alperen Çağrı",
        "Email": "info@alperen.com",
        "Phone ":5056784534,
        "Adres":"Van",
         "Doğum Tarihi": 1980,
        "Ünvan":"Matematik Öğretmeni",
        "mezuniyet yılı":2005,
        "Hobiler": "balık tutmak",
         "ingilizce":"başlangıç",
        "iş deneyimi":"MEB de Çalışıyor"
         },
    
    '4':{                                           #Each dictionary should represent a cv.
        "Name and Surname":"Elvan Yas",
        "Email": "info@elvan.com",
        "Phone ":"5532265434",
        "Adres":"USA",
         "Doğum Tarihi": 1994,
        "Ünvan":"Yazılım Mühendisi",
        "mezuniyet yılı":2018,
        "Hobiler": "SATRANÇ",
         "ingilizce":"ileri seviye",
        "iş deneyimi":" SOFTWARE ENGİNEER İN AMAZON halen"
         },
    
    '5':{                                           #Each dictionary should represent a cv.
        "Name and Surname":"Selim Adıgüzel",
        "Email": "info@mselim.com",
        "Phone ":"5324567890",
        "Adres":"İstanbul",
         "Doğum Tarihi": 1990,
        "Ünvan":"Müfettiş Yardımcısı",
        "mezuniyet yılı":2017,
        "Hobiler": "tenis",
         "ingilizce":"orta seviye",
        "iş deneyimi":"2018-2020 Teb "
         },
}
        


while True:
    print( "1.Selma Tosun \n",
         "2.Mert Günok\n",
         "3.Alperen Çağrı\n",
         "4.Elvan Yas\n",
         "5.Selim Adıgüzel\n"
         )
    username = input("Enter the list number to view the person's resume:" ) #The CV she wanted to view was asked.
    kullanıcı=users[username]
   
    for i,j in kullanıcı.items():
        print("\n",i,":", j)       #The desired CV information is printed.
    print("\n...........................................\n")
