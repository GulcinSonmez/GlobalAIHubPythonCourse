# %%
#FİNAL_PROJECT GÜLÇİN SÖNMEZ

print(".............BİLGİ YARIŞMASI..........\n\nDiKKAT:\n-Her soru 10 puandır!\n-50 puan ve üstü alırsanız başarılı sayılırsınız!\n-BAŞARILAR!\n")

#3 lists named questions, options and answers were created.
#It consists of 10 questions in total
sorular=[
         ("SORU 1:\n Otomatik vitesli arabalarda hangisi yoktur?"),
         ("SORU 2:\n Zeytinin en çok yetiştiği bölge?"),
         ("SORU 3:\n Hangisi bir su markası değildir? "),
         ("SORU 4:\n Romatolog bir doktor ne ile uğraşır ?"),
         ("SORU 5:\n Hangi Hükümdar timur tarafından esir edilmiştir? "),
         ("SORU 6:\n Voleybolda bir takımın sahada kaç oyuncu bulundurabilme hakkı vardır? "),
         ("SORU 7:\n Skyfall filminin müziğini kim yapmıştır? "),
         ("SORU 8:\n Hangisi taş devri karakteri değildir? "),
         ("SORU 9:\n 27-4x 3/(8+4) kaçtır? "),
         ("SORU 10:\n Hangi ünlü yazar daha önce doğmuştur? ")]

şıklar=[("   A) Vites B) Debriyaj C) Fren D) Gaz"),#1
          (" A) Ege   B) Akdeniz  C)Karadeniz  D) Iç anadolu" ), #2
          (" A)Evian  B)Aqua C)Tobleron D)Sırma "), #3
          (" A)Eklem ağrısı B)Kanser C)Alzheimer D)Baş ağrısı "), #4
          (" A)Yıldırım Bayezid B)Fatih Sultan Mehmet C)II.Abdülhamit D)II.Selim "), #5
          (" A)5  B)6  C)7  D)4"), #6
          (" A)Adele B)Rihanna  C)Hans zimmer  D)Ennio morricone "), #7
          (" A)Fred  B)Vilma  C)Bay Slate D)Dorlock"), #8
          (" A)23 B)24  C)25 D)26"), #9
          (" A)Yaşar Kemal B)Orhan Kemal C)Yahya Kemal D)Namık Kemal"),] #10

#Each question has only one answer.   
cevaplar=["B", "A", "C" , "A", "A","B","A","D","D","D"]


def inform():
    
    toplam_puan= 0 
    for x in range(10):
        soru_sayısı=x
        
   
        print(sorular[soru_sayısı])
        print(şıklar[soru_sayısı])
        answer = input('Cevabınız:  ')
        
        if (answer.upper() == cevaplar[soru_sayısı]): #Answers to questions are adjusted according to case sensitivity
            
            print('Tebrikler! Doğru Cevap.\n\n')
            toplam_puan += 10  #Each question is worth 10 points.
            
        else:
            print('Cevabınız Yanlış. Doğru Cevap',cevaplar[soru_sayısı],' Şıkkı.\n\n')
           
    

    if toplam_puan >= 50 :                 #If the user answered more than 5 questions correctly, it was deemed successful.
        print("BAŞARILISINIZ,TEBRİKLER!")
    else:
        print("MAALESEF BAŞARAMADINIZ!")   #Failed if user answered 5 or fewer questions.
    
    print("."*50)    
    print('Bilgi Yarışmamız Bitmiştir. Toplamda {} Puan Aldınız!'.format(toplam_puan))
    print("."*50)
            
inform()
